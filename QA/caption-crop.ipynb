# %%
import torch
from PIL import Image
from transformers import (
    AutoModelForImageTextToText,
    AutoProcessor
)
import matplotlib.pyplot as plt
import glob
import random
from nuscenes.nuscenes import NuScenes

import numpy as np
import json
import yaml

model_id = "Ertugrul/Qwen2.5-VL-7B-Captioner-Relaxed"
DATA_ROOT = '/users/bangya/projects/vlm/nuscenes-data'
DATA_VER = 'v1.0-trainval'
nusc = NuScenes(version=DATA_VER, dataroot=DATA_ROOT, verbose=True)

# the model requires more than 16GB of VRAM, 
# if you don't have you can use bitsandbytes to quantize the model to 8bit or 4bit
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...
# 23 category,
# 8 attribute,
# 4 visibility,
# 64386 instance,
# 12 sensor,
# 10200 calibrated_sensor,
# 2631083 ego_pose,
# 68 log,
# 850 scene,
# 34149 sample,
# 2631083 sample_data,
# 1166187 sample_annotation,
# 4 map,
# Done loading in 22.551 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 7.1 seconds.
# ======

# %%
model = AutoModelForImageTextToText.from_pretrained(
  model_id,
  device_map="auto",
  torch_dtype=torch.bfloat16,
  attn_implementation="flash_attention_2", # Use "flash_attention_2" when running on Ampere or newer GPU or use "eager" for older GPUs
)

# you can change the min and max pixels to fit your needs to decrease compute cost to trade off quality
min_pixels = 256*28*28
max_pixels = 1280*28*28

processor = AutoProcessor.from_pretrained(model_id, max_pixels=max_pixels, min_pixels=min_pixels)

def generate_description(path, model, processor, prompt):
    system_message = "You are an expert image labeller."

    image_inputs = Image.open(path).convert("RGB")
    messages = [
        {
            "role": "system",
            "content": [{"type": "text", "text": system_message}],
        },
        {
            "role": "user",
            "content": [
                {"type": "text", "text": prompt},
                {"type": "image", "image": image_inputs},
            ],
        },
    ]
    text = processor.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )

    inputs = processor(
        text=[text],
        images=image_inputs,
        padding=True,
        return_tensors="pt",
    )
    inputs = inputs.to(model.device)
    
    # min_p and temperature are experemental parameters, you can change them to fit your needs
    generated_ids = model.generate(**inputs, max_new_tokens=512, min_p=0.1, do_sample=True, temperature=1.5)
    generated_ids_trimmed = [out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)]
    output_text = processor.batch_decode(
        generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
    )
    return output_text[0]
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
def validate(caption):
    bad_words = ["photo", "image", "picture"]
    for word in bad_words:
        if word in caption:
            print(f"bad word: {word}")
            return False
    return True

def captioning(img_path, verbose=False):
    instance_token = img_path.split("/")[-1].split(".")[0]
    nusc_instance = nusc.get('instance', instance_token)
    category_name = nusc.get('category', nusc_instance['category_token'])['name']
    hint = category_name.split(".")[-1]

    prompt = "Provide a short noun phrase captioning the single object in a street scene."
    "such as 'black sedan with red logo' or 'man in a blue t-shirt and jeans'."
    "Must illustrate object colors.  "
    "simply describe the object, do not judge on the image"
    f"(stick to hint {hint}). TEN words max."



    img = Image.open(img_path)
    if img.size[0] < 28 or img.size[1] < 28:
        print(f"image too small: {img_path}")
        return None

    if verbose:
        try:
            plt.close()
        except:
            pass
        print(f"hint: {hint}")
        plt.axis('off')
        plt.imshow(img)

    description = generate_description(img_path, model, processor, prompt)

    # grey = img.convert("L")
    # grey_pixels = np.array(grey)
    # avg_brightness = grey_pixels.mean()
    # darkness = 1 - (avg_brightness / 255)
    # print(f"darkness: {darkness:.2f}")

    # return(description)

    description = description.lower().strip()
    cap = description.replace("A ", "the ").replace("a ", "the ")
    cap = cap.split(".")[0]
    if not cap.startswith("the"):
        cap = "the " + cap

    if not validate(cap):
        print(f"invalid caption: {cap}")
        return None
    
    return cap

# %%
root = "./instance_crops"
dump_path = "./captions.yaml"
scenes = glob.glob(f"{root}/*")

with open(dump_path, "r") as f:
    history = yaml.safe_load(f)

for sc in scenes:
    images = glob.glob(f"{sc}/*")
    sc_name = sc.split("/")[-1]
    if sc_name in history:
        print(f"Already processed {sc_name}, skipping...")
        continue
    if len(images) == 0:
        print(f"No images found in the directory: {sc}")
        continue
    print(f"Processing {len(images)} images in {sc_name}...")
    sc_objs = {}
    for image_path in images:
        obj = image_path.split("/")[-1].split(".")[0]
        cap = captioning(image_path)
        if cap is None:
            print(f"Failed to caption image: {image_path}")
            continue
        sc_objs[obj] = cap

    with open(dump_path, "a") as f:
        yaml.dump({sc_name: sc_objs}, f, default_flow_style=False, width=float("inf"))
# Out:
# Already processed 8180a1dbbba3479bb0c7f4ff6e9a3f0e, skipping...
# Already processed 9c83e438973e4824853e6a38928ca4ff, skipping...
# Already processed c6da5920d2bc459bb3bc51ee6b9fdd7e, skipping...
# Already processed f5b29a1e09d04355adcd60ab72de006b, skipping...
# Already processed 16be583c31a2403caa6c158bb55ae616, skipping...
# Already processed 01796494e25c448dadaba70cfcc3532d, skipping...
# Already processed 73d9a36f20594e658020ebfc5b0ba74a, skipping...
# Already processed a99120daccb24bcd941b33e6e03bf718, skipping...
# Already processed 9c5dc664216e43a99d5da3f23d373e4d, skipping...
# Already processed 8b60e7e47cde43e0a7fbd66d926de14f, skipping...
# Already processed 63252988084b4943a50734990c47e039, skipping...
# Already processed 3bc4553925494890a21ef7a15c40eaed, skipping...
# Already processed 4431d97ea17044ad9c09c13d16684054, skipping...
# Already processed 2c96ff6afc9e4cf7bc8b107fce955c1f, skipping...
# Already processed 7bd098ac88cb4221addd19202a7ea5de, skipping...
# Already processed bd850592cd2541288b177b8e20baa31e, skipping...
# Already processed 28db6ee9a8d34e9e88e741817b6733c1, skipping...
# Already processed 5c76a3728b8b4d02ae20bd69fb928aa1, skipping...
# Already processed 991d65cab952449a821deb32e971ff19, skipping...
# Already processed 74d03e3b673f4a72a3f76e1b0c7840bd, skipping...
# Already processed 3289046b886f4c98a676bd7e6a3c6ef1, skipping...
# Already processed 212fd4c9c9174635a7ec76051c8eec9e, skipping...
# Already processed 268099669c954f429087081530094337, skipping...
# Already processed d4c560022dda448dabb0b60fb62dd6ba, skipping...
# Already processed 5a1d2867bb504c888a628ad549cc10b6, skipping...
# Already processed 62d9a581c7114d90a48bacfb2a47b104, skipping...
# Already processed 75ebb308bea04317adbc25554d5cd7f5, skipping...
# Already processed 8931a57994764c9b945a7a1b352c9ae5, skipping...
# Already processed c6072dd4f7cc47efaad77889aa465ad6, skipping...
# Already processed 928ee3a8c5a84497a6360fe70a4e921e, skipping...
# Already processed 448cf480b0b8400a86881d28c2c5f734, skipping...
# Already processed affb0caa5d2948f98cee5c42c7aefc1c, skipping...
# Already processed ca6e45c25d954dc4af6e12dd7b23454d, skipping...
# Already processed 83ffc453d209404781ea4574d77adb22, skipping...
# Already processed 860ef56791a947baadb27dd00bd5d4b3, skipping...
# Already processed dcdea563c77544bb887de11d87619d3c, skipping...
# Already processed 41e0d46e715a476ab05e4d62e415ea41, skipping...
# Already processed 2f56eb47c64f43df8902d9f88aa8a019, skipping...
# Already processed dbd9183e1278475ea54761297e004b04, skipping...
# Already processed 3927699fa562451a98bb13bf8405361d, skipping...
# Already processed ed22649f50454a6ab71356780b2a2454, skipping...
# Already processed a8bd4c1efe284a5bba46f59454764965, skipping...
# Already processed 590b4e5a4f94426ab3b1a66f35e140d5, skipping...
# Already processed 45275e709d4a4b0592d57850d8e8bd8d, skipping...
# Already processed 4962cb207a824e57bd10a2af49354b16, skipping...
# Already processed 76b36918bd4c487581a4196ffd1b1434, skipping...
# Already processed 3359935281a34136992997acab7cdddd, skipping...
# Already processed 5aa5225d0ef440519a31c1dde075dab7, skipping...
# Already processed ab5bc0504e2c4103ab306c5bd18f6791, skipping...
# Already processed 93036f2be8de445aad06b727b848cea5, skipping...
# Already processed b09162caded44198b149b4bce3558056, skipping...
# Already processed a04daf2d0f194b2ab2ff2a47dfebc1d7, skipping...
# Already processed 64bfc5edd71147858ce7446892d7f864, skipping...
# Already processed 762e6aac0d6f4c1b9b0286ab4b2da654, skipping...
# Already processed 01452fbfbf4543af8acdfd3e8a1ee806, skipping...
# Already processed 19dce2ebc7bd4f138aea6d645a4afec7, skipping...
# Already processed 38b3010304734913bb148d17ebbc352b, skipping...
# Already processed c133e78e55ae487c821803a3b183d1ab, skipping...
# Already processed bd338b912ce9434995b29b6dac9fbf1d, skipping...
# Already processed 2d8e61ea27fd419ba9b708488e3f2f10, skipping...
# Already processed a6daedc3063b421cb3a05019e545f925, skipping...
# Processing 37 images in fe4fdd7a28754baeac7074ad78f55a52...
# /local_data/miniconda/envs/vlm/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2787: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# bad word: image
# invalid caption: the blurry black-and-white street scene, with indistinct shapes and lines suggesting parked cars, buildings, or pedestrians, and the overall image is grainy, making specific details difficult to discern
# Failed to caption image: ./instance_crops/fe4fdd7a28754baeac7074ad78f55a52/e455d1eee8fe4bad80dec39c49d2915a.jpg
# Processing 33 images in 1d914f73a4a243c3acac50d24f083aac...
# Processing 11 images in bc219c0fa63b43b4b9dddab47fce1fef...
# Processing 6 images in 53e8446852bf488bb1b09ae032918bbd...
# Processing 4 images in f12b4e7fb95646ec9dac305076024bb9...
# Processing 19 images in b0b26c1e5a1140e69598422f12ae1dc0...
# Processing 9 images in 91f797db8fb34ae5b32ba85eecae47c9...
# Processing 14 images in cdeb0e85e43e481a87b2251351e10c2f...
# bad word: image
# invalid caption: the blurry image of the car at night, likely taken with motion blur due to the vehicle's movement, on the dimly lit street with indistinct background elements like buildings and streetlights
# Failed to caption image: ./instance_crops/cdeb0e85e43e481a87b2251351e10c2f/dff66c76e685454dad094dc39394a88c.jpg
# Processing 8 images in cd1a8954ff904333bb13fa1a6ee526fd...
# Processing 37 images in 2131d9fd2c48418081875019e35cf6a2...
# Processing 20 images in 5e30d846d2344ec2addfb664799d1899...
# bad word: photo
# invalid caption: the blurry photo of the man sitting in the chair, legs extended and shoes visible, in the dimly lit, indoor setting
# Failed to caption image: ./instance_crops/5e30d846d2344ec2addfb664799d1899/76306be97c7945ee95867c69df1fb567.jpg
# Processing 14 images in 2575c1870ede486b8568279b4731e47e...
# Processing 11 images in 9068766ee9374872a380fe75fcfb299e...
# Processing 7 images in 19d97841d6f64eba9f6eb9b6e8c257dc...
# Processing 24 images in de7d80a1f5fb4c3e82ce8a4f213b450a...
# bad word: photo
# invalid caption: the blurry photo of the parked car at night
# Failed to caption image: ./instance_crops/de7d80a1f5fb4c3e82ce8a4f213b450a/7b8032aef1494ed28eb726c0fe7b7be7.jpg
# bad word: image
# invalid caption: the image shows the street scene with blurred headlights of multiple cars visible, indicating motion and possibly the night setting due to the darkness surrounding the headlights
# Failed to caption image: ./instance_crops/de7d80a1f5fb4c3e82ce8a4f213b450a/5239af09678744329fe215bedc5fe6fb.jpg
# bad word: photo
# invalid caption: the blurry photo of the blue traffic cone
# Failed to caption image: ./instance_crops/de7d80a1f5fb4c3e82ce8a4f213b450a/9441225cd01f4730a02b5d8927063f53.jpg
# Processing 32 images in 010fb5bcc7984d0f8f07f99e02366df1...
# bad word: image
# invalid caption: the black jeep in blurry image
# Failed to caption image: ./instance_crops/010fb5bcc7984d0f8f07f99e02366df1/3e5243d856444f928eae653e673e81a7.jpg
# Processing 26 images in 62696ecd66a3445da436ce2d87ee3501...
# Processing 13 images in fd2d419d4cf84a2d84922b9b7d2cea4d...
# Processing 9 images in d90b94e8bfd446cd9407f48665122268...
# Processing 7 images in 673ce9bdd9254fff82a524653a07b57f...
# Processing 37 images in 35ecd252b8ee4cbc83376148e192a803...
# Processing 19 images in 76c632788f8c4516bef1c4297f2002f6...
# bad word: image
# invalid caption: the blurred image of the man in casual attire walking on the street
# Failed to caption image: ./instance_crops/76c632788f8c4516bef1c4297f2002f6/12454c87e6244dcbb141bcaaeccfa554.jpg
# Processing 6 images in 6207269cb9474c14b01f9610b2ee30aa...
# Processing 29 images in bed8426a524d45afab05b19cf02386b2...
# bad word: photo
# invalid caption: the blurred street photo of the person
# Failed to caption image: ./instance_crops/bed8426a524d45afab05b19cf02386b2/880d4bcd113b431aa50728aee54c8ba4.jpg
# Processing 17 images in e329b73341204af7a9de29e65291ce1c...
# Processing 3 images in 1623e7fab5174f2a84cf1b539233e3a6...
# Processing 7 images in 43017e1e57174925ae241b2ebff7991b...
# Processing 28 images in d29527ec841045d18d04a933e7a0afd2...
# Processing 12 images in 0ced08ea43754420a23b2fbec667a763...
# Processing 9 images in e323a27a0ba94ab5ab11010d778cd41f...
# bad word: photo
# invalid caption: the close-up, high-resolution photograph of the large, silver semi-truck in the nighttime parking lot
# Failed to caption image: ./instance_crops/e323a27a0ba94ab5ab11010d778cd41f/ee82b17d544742e0906b20db0b195390.jpg
# Processing 23 images in 1ec0b9bc3eca4b76b2610c519f843762...
# Processing 10 images in c075fbdd97124beaba95bc5c25149f30...
# Processing 15 images in 0287702725184161af95373198546a59...
# Processing 17 images in 7ad94b6e54f641208bf59cba6bb55220...
# Processing 48 images in fd0d4fdda5c04f7eb43ecd2097df56fa...
# Processing 14 images in 57146b2ebf10432f84b15a3038fe1755...
# Processing 5 images in 8cf06ee8cd004478aa46f391310b923e...
# Processing 13 images in f29904c2bcdc4d78bbcac75a2b30fe38...
# Processing 27 images in 129304d659464b0fb3a51c99eaec114a...
# Processing 9 images in 0be1ff07a8f148ca9535fb7f0deaf828...
# Processing 40 images in 181bf34123514c329e2cef72847607a4...
# Processing 6 images in e8834785d9ff4783a5950281a4579943...
# Processing 35 images in 2ba06ef7b3b44cbfad6d771981d86af9...
# Processing 7 images in 034256c9639044f98da7562ef3de3646...
# Processing 12 images in c3e0e9f6ee8d4170a3d22a6179f1ca3a...
# Processing 14 images in 91c071bcc1ad4fa1b555399e1cfbab79...
# Processing 4 images in 19640fe4b6894f97b16e0faad51432b4...
# bad word: photo
# invalid caption: the blurry night photo, likely captured on the high-speed train
# Failed to caption image: ./instance_crops/19640fe4b6894f97b16e0faad51432b4/c34dad7c508d455abab4736c88037a90.jpg
# Processing 14 images in 1e9283d1ce98428aaa3b851487eb4f58...
# Processing 3 images in b789de07180846cc972118ee6d1fb027...
# Processing 4 images in cb3ef7b7ef124983b336c781f134cdfb...
# Processing 9 images in 5a2aac9df32945d183fc81924ff148b6...
# Processing 9 images in 2cc8ffb250c44b42a888e9185810e04c...
# Processing 3 images in 6bb64043c9db4f51b7a69e7260ed4f6e...
# Processing 21 images in 7e8ff24069ff4023ac699669b2c920de...
# Processing 3 images in 4efde86424ea4088a43faeb5158ceabf...
# Processing 1 images in 4bf8fb20e4744bd391beb07b2424b30a...
# Processing 6 images in 7f03cd19d9cc4381a591fca00666d7ed...
# Processing 6 images in 48ff8fee13c344ed843af3eec8f9b94b...
# Processing 27 images in 66e050dbde3447e5a4b07f0d896f5864...
# Processing 24 images in 30783e1b472a4101b82be19e41636ba2...
# bad word: image
# invalid caption: the blurry image of the vintage car driving on the street
# Failed to caption image: ./instance_crops/30783e1b472a4101b82be19e41636ba2/2539437bce874eb88a4a4bcb78e4371a.jpg
# Processing 5 images in f9e460f092c94466b1211704b5a8859d...
# Processing 18 images in 4f18d9a7ed374a0fb93c026589dcf9a0...
# bad word: photo
# invalid caption: the image is the photograph capturing the side profile of the green suv parked in an outdoor parking lot during what appears to be early morning or late evening, indicated by the soft lighting
# Failed to caption image: ./instance_crops/4f18d9a7ed374a0fb93c026589dcf9a0/b89063b54597428193b819de233ba2ff.jpg
# Processing 4 images in eba4b7c19b5f48289e105937d03e5222...
# Processing 11 images in a2b64d02c5fa4b9bab671a97561b6b33...
# Processing 11 images in 3b2ee26cb8484f77895bc336663df502...
# Processing 4 images in c8e6213038884d05907b1edd7e55552e...
# Processing 19 images in 2bd47eabb64d4499862388cec180a7d1...
# Processing 1 images in a1e7cd557b9541dbb00822ea0c56204b...
# Processing 17 images in dc6235e2281943548084c484cb38b876...
# image too small: ./instance_crops/dc6235e2281943548084c484cb38b876/c8b383a7df1945b6a01d7c9459e3b900.jpg
# Failed to caption image: ./instance_crops/dc6235e2281943548084c484cb38b876/c8b383a7df1945b6a01d7c9459e3b900.jpg
# Processing 40 images in fccdb073bc54449a99f033e040ad51a2...
# Processing 7 images in c3ab8ee2c1a54068a72d7eb4cf22e43d...
# Processing 15 images in 77c23b25e2ee4b9ebff6d179d3ce4a31...
# Processing 7 images in 7061c08f7eec4495979a0cf68ab6bb79...
# Processing 5 images in 4b48dfc43a3f411b88a71031d77e5696...
# Processing 8 images in 4b5bf3f4668d44fea9a676e9c4a8a79e...
# Processing 8 images in 6520b5f0d568414c973f791b30ee1548...
# Processing 7 images in bfe368f8c6a44efcb323a82f6974a9a6...
# Processing 5 images in 9eaabad9385b4fe1b9f397edead326ac...
# Processing 11 images in 2911b04ae82a45f386ad4f79457dd73f...
# Processing 5 images in 359f9c029ae44e1d9d47c05bc7915561...
# Processing 27 images in 3034b3f33e1d49f4a7b6c84bdea57004...
# bad word: photo
# invalid caption: the blurry, low-resolution photo capturing two men standing on the city sidewalk
# Failed to caption image: ./instance_crops/3034b3f33e1d49f4a7b6c84bdea57004/71a6317b87364433ab145faf15fbc399.jpg
# Processing 14 images in e7ef871f77f44331aefdebc24ec034b7...
# Processing 23 images in 54f56f80350b4c07af598ee87cf3886a...
# Processing 13 images in daa9fce50073470398da3c2bccdaf21b...
# Processing 12 images in 7365495b74464629813b41eacdb711af...
# Processing 14 images in ef5f216134a94e308697ab4c75402a20...
# Processing 18 images in 2eb4d7f00e584a548aa0b899638bfb0a...
# Processing 2 images in 9047b53fd41540649dce014a128cbe1b...
# Processing 23 images in 7d6006ae9d8f406aa99756156ea4f70a...
# Processing 39 images in 9a0d2af517ff44f587c93254ee657215...
# bad word: image
# invalid caption: the image is too blurry to provide the precise object description
# Failed to caption image: ./instance_crops/9a0d2af517ff44f587c93254ee657215/d4216e13176e4182b1014905282ccd45.jpg
# Processing 21 images in deab903b0b644d7a984c552968026631...
# Processing 11 images in 82aa6c89bbf744a6a5a12cc171d8376e...
# Processing 12 images in b0525843a3b0463f91d715deff733b8f...
# Processing 6 images in 01c8c59260db4a3682d7b4f8da65425e...
# Processing 8 images in 724957e51f464a9aa64a16458443786d...
# Processing 6 images in 55c853d5aab04850a8059dc95e62c2ad...
# Processing 11 images in a59b6db922ff490da5ccfc9980700935...
# Processing 26 images in 53d376c20b7146349a53554a4616c48c...
# Processing 2 images in d01e7279da2649ef896dc42f6b9ee7ab...
# Processing 47 images in dbfd4af0e0d744858e796ec69826e673...
# bad word: image
# invalid caption: the silver sedan car with blurred image
# Failed to caption image: ./instance_crops/dbfd4af0e0d744858e796ec69826e673/c422d08f36214cb8a46b070a4e4126e7.jpg
# Processing 5 images in 7052d21b95fc4bae8761b8d9524f3e42...
# Processing 7 images in 1be49200788d4e38ae4496b27b233ccb...
# Processing 7 images in bc5daf905b854dbc8944811c4b7c319d...
# bad word: photo
# invalid caption: the blurred photograph of the car in motion
# Failed to caption image: ./instance_crops/bc5daf905b854dbc8944811c4b7c319d/6c929bc6764f474786d77deae5c33fc6.jpg
# Processing 5 images in 2121cc12888e47ce856dc5391f202594...
# Processing 12 images in 6d4b2bd795ae4c66900ad98ccd2371a6...
# Processing 3 images in b886756c3fd641eeba9dda3932e196c0...
# Processing 9 images in a8819942e8bb43b6a832c56dfb78cfc6...
# Processing 4 images in f612aec0c3e34e32b2e9e48670cdecca...
# Processing 3 images in ed242d80ccb34b139aaf9ab89859332e...
# Processing 35 images in fcbccedd61424f1b85dcbf8f897f9754...
# Processing 9 images in 7ad327c8827849ed91136bb2d04acec9...
# bad word: image
# invalid caption: the pedestrian in crosswalk, blurred image
# Failed to caption image: ./instance_crops/7ad327c8827849ed91136bb2d04acec9/001af0f00b314abc89adcc5641c4772b.jpg
# Processing 9 images in f0294478e1994642bac453f1e84610df...
# Processing 5 images in 26c089d84086473e87607ae5c6ae85c6...
# bad word: photo
# invalid caption: the blurred photograph of the street scene at night
# Failed to caption image: ./instance_crops/26c089d84086473e87607ae5c6ae85c6/20a67c190a8b446fb2babd86a701f6b6.jpg
# Processing 18 images in 7937f7d56b5444fd8c55052460e23807...
# bad word: photo
# invalid caption: the image is the dark, grainy photograph taken at night, capturing the blurry and indistinct street scene
# Failed to caption image: ./instance_crops/7937f7d56b5444fd8c55052460e23807/eba30f88e5c24ab1befc5745a9fd0dfb.jpg
# Processing 12 images in a5003bf9af8545a3a4c7f1f5604e8d3b...
# bad word: image
# invalid caption: the blurry image of the car with headlights on
# Failed to caption image: ./instance_crops/a5003bf9af8545a3a4c7f1f5604e8d3b/403c761001024fdabe152f318d41ec8b.jpg
# Processing 12 images in 7b4a37ecca84421fbc22ad15e8b00ed8...
# Processing 9 images in f77e66f97d204b5da547f6c007dc2abf...
# bad word: photo
# invalid caption: the blurred photograph of the young woman standing on the sidewalk, wearing the blue and white patterned dress and white high heels, with the small, light-colored bag hanging from her right arm
# Failed to caption image: ./instance_crops/f77e66f97d204b5da547f6c007dc2abf/f9b34642edfb4a0f9656d0a8ee00a4a1.jpg
# Processing 6 images in dcd5bc29543747e28ef02816dd458290...
# Processing 15 images in 8377abf77f464a9cb62eacf63f383422...
# Processing 45 images in 3ada261efee347cba2e7557794f1aec8...
# bad word: photo
# invalid caption: the blurry photograph of the white sedan in traffic, taken from the driver's perspective
# Failed to caption image: ./instance_crops/3ada261efee347cba2e7557794f1aec8/3b89e982ed2445e8961d36e92947a9bb.jpg
# Processing 1 images in e0a212aafd574781b122a6ba66599a1e...
# Processing 53 images in 491322eec05043c9907c59aa35b046ea...
# bad word: image
# invalid caption: the blurry image of the gray rectangular object on the concrete sidewalk
# Failed to caption image: ./instance_crops/491322eec05043c9907c59aa35b046ea/6b108e6e8b914c509fbca86c23d748dc.jpg
# bad word: photo
# invalid caption: the close-up photograph of the wet, dark gray sidewalk with water reflections, smooth concrete surface, wetness due to rain or recent cleaning, and the textured stone or concrete wall to the left with the horizontal seam, clean lines, and the slightly worn appearance, indicating age or heavy use
# Failed to caption image: ./instance_crops/491322eec05043c9907c59aa35b046ea/3738c30f933341599bd0d7587a0a5f2b.jpg
# Processing 27 images in b07358651c604e2d83da7c4d4755de73...
# bad word: picture
# invalid caption: the man taking picture with camerthe on street
# Failed to caption image: ./instance_crops/b07358651c604e2d83da7c4d4755de73/a362ab870c4741ff8fd7294815ba1ea2.jpg
# Processing 5 images in 931c5c57011944459bba3825ab8777a9...
# Processing 1 images in 93481c2504474ca0b21d4abbab2cf3cf...
# Processing 10 images in 10dfdae842b543938a230f25a1e9f934...
# Processing 12 images in 221a67d95acf448ba863917ec4d32ed0...
# Processing 29 images in 2f9da038274a4448bdbb83f994fc6381...
# bad word: image
# invalid caption: the blurred image of the parked dark suv
# Failed to caption image: ./instance_crops/2f9da038274a4448bdbb83f994fc6381/12e8b938bc984ecf916d7d60bd782088.jpg
# Processing 14 images in 9a1188aba4bf458c8220818a6c0be55a...
# Processing 11 images in d987908d74794138b07d1237887bb441...
# Processing 15 images in 1466f33b56704942a368fa03d10708dd...
# Processing 14 images in 103b54209e584cd4b7ed2890eca2e126...
# Processing 4 images in b3f63d06b6c54ae6ae80d688f4966408...
# Processing 27 images in dce6f3f2bf6b4859abcf3268581969d3...
# bad word: photo
# invalid caption: the blurred photograph of the black sedan car
# Failed to caption image: ./instance_crops/dce6f3f2bf6b4859abcf3268581969d3/dfb2185e51594185a0979d997dcd5a91.jpg
# Processing 53 images in cd122d67c51c4fa4902486897cad91ad...
# bad word: photo
# invalid caption: the image is the low-resolution photograph featuring the vintage car, likely from the 1950s or 1960s, parked on the street
# Failed to caption image: ./instance_crops/cd122d67c51c4fa4902486897cad91ad/d8561da8c01b4c5eaaed21c14776632d.jpg
# Processing 12 images in 261e8288cf5647e396ab584e210e4ba1...
# Processing 1 images in d0b2d916178a402a842c88f394d7d7e8...
# Processing 25 images in b51869782c0e464b8021eb798609f35f...
# Processing 18 images in 6d6314f1865343f987ca53107b694745...
# Processing 1 images in 76ceedbcc6a54b158eba9945a160a7bc...
# Processing 38 images in df8dfada99a04a81bd1b102eeb84e9bc...
# Processing 14 images in 37a37b06ba5e4f978fc6cb77e90f2498...
# Processing 10 images in 8d8728879b89405eba3f8ce1af138cb2...
# bad word: image
# invalid caption: the nighttime street scene, car tail lights glowing red, asphalt wet, city life, blurred image
# Failed to caption image: ./instance_crops/8d8728879b89405eba3f8ce1af138cb2/c4382e6d86cd4d6caa27014d7a82073d.jpg
# Processing 13 images in 45fc8a7a26c5469a88db999ae8468777...
# Processing 2 images in 2bfb95d8ba3a4c11869f4d6635784640...
# Processing 16 images in dc9ef63b61394d3d8effeb51919f2144...
# Processing 6 images in 1959c8f440a340fda3ea2cac0ac528ec...
# Processing 8 images in 03a8a37d5d444674bae34336e78ac39d...
# Processing 9 images in 102b894332464704900264216480a8f7...
# Processing 2 images in c6d1085c40614693a046dae3168bdb35...
# bad word: photo
# invalid caption: the slightly out of focus, blurry photograph, captured from the vehicle window in motion at night
# Failed to caption image: ./instance_crops/c6d1085c40614693a046dae3168bdb35/6072dfbab3b9423da1a2113f32f8a00a.jpg
# Processing 4 images in c0990deaa8954a54afc86f7710f349a1...
# Processing 15 images in 892ed06c432448fe87ecb5d31756f14a...
# Processing 36 images in 7f8714d8ca814914bf4ff3ed30123db5...
# bad word: photo
# invalid caption: the blurry street photo of three individuals in the public space
# Failed to caption image: ./instance_crops/7f8714d8ca814914bf4ff3ed30123db5/9fcffaf4298647a6b2a723362ccfbe6a.jpg
# Processing 7 images in ae643c14ded14e6ea74f8c8605200ed1...
# Processing 16 images in 1aa633b683174280b243e0a9a7ad9171...
# Processing 19 images in 47cfdbcf14fe47d2a3b9e7e5b46d8a36...
# Processing 1 images in 3673601f263947fd9259640bd55622bd...
# Processing 22 images in 69ee276c40644ddbb7fe21c613cd7689...
# Processing 16 images in 4db0eee3b82d49b198c1a411cf7f7d68...
# Processing 34 images in 947308824ada42fdbcff7009e815287f...
# Processing 11 images in 52bb785dcb5548a1836898f14fb3cf6d...
# Processing 23 images in 55b3a17359014f398b6bbd90e94a8e1b...
# Processing 8 images in 78f63999591a49a195b872ddc368a146...
# Processing 12 images in fd5a3c6d3ad44954a8045edbe9d93763...
# Processing 16 images in 2fc3753772e241f2ab2cd16a784cc680...
# Processing 4 images in b7bb8ec5bf22476f8ba8ca0b2e57e8f6...
# Processing 1 images in 5c9bd7ead37e4aa9989f7909f3a78baa...
# Processing 8 images in 84e056bd8e994362a37cba45c0f75558...
# Processing 6 images in 9a61a88ed9094334a73aa93c08222110...
# Processing 2 images in 4bb9626f13184da7a67ba1b241c19558...
# Processing 7 images in 01e4fcbe6e49483293ce45727152b36e...
# Processing 10 images in 77b27e26bf6d4c38859ccfa076cee51d...
# Processing 12 images in 087c6e521e974c708d49cac1db095691...
# Processing 10 images in 8461c1125eaf46c7abaf4ee18e8c4ee6...
# Processing 23 images in 5035adcd18d34d4783c2ccb41db998c1...
# Processing 35 images in 6308d6d934074a028fc3145eedf3e65f...
# Processing 3 images in 82aef599650d462db73731b7ff40918b...
# Processing 6 images in fc61f52dcc1b4def95a278665d23af00...
# Processing 8 images in 8c45a7a9142f4f848d463cc46843db71...
# Processing 7 images in e5514b8f435e475cac4eba74b44773b5...
# Processing 9 images in 4d475873416a4860900f5af213e0027c...
# Processing 12 images in 634e7fbfe29c4a72b1ceb692b1d2ab44...
# Processing 2 images in c04cdbbe744c4da08d3df61c47d5cc94...
# Processing 27 images in bebf5f5b2a674631ab5c88fd1aa9e87a...
# Processing 19 images in 7e2d9f38f8eb409ea57b3864bb4ed098...
# Processing 42 images in 8c7dfcee70754286959b80c6cfe2d246...
# bad word: photo
# invalid caption: the blurry photo captures the concrete bridge beam with two small holes, indicating wear or damage, as the dark shadowy figure looms below, adding an element of intrigue or foreboding
# Failed to caption image: ./instance_crops/8c7dfcee70754286959b80c6cfe2d246/3e747430af2c40a99079313f32e074ec.jpg
# Processing 14 images in f123185f3bb64faebc08d4453aec2659...
# Processing 6 images in 240d15482599449a9bd0432fbfa688ab...
# Processing 26 images in 827712f3e79340d8878de0202c5b3960...
# Processing 2 images in aedcd3cf7c4a49d7a4a43ab7443a9eb1...
# Processing 43 images in a2e8f126913b4f72909e06d881dc5a8b...
# Processing 6 images in febc1800b9ed432d96aee5ecf0156831...
# Processing 15 images in d865cb18632040fdb4cb06b6e3331cdb...
# Processing 3 images in ef5f945852e84fcc88cab506746a6636...
# Processing 16 images in e3b6fe9201c64334be311d4249a0c80e...
# Processing 7 images in 112ca771e318478a88cfa692f61ffcac...
# Processing 34 images in 3045ed93c2534ec2a5cabea89b186bd9...
# bad word: photo
# invalid caption: the blurry photograph of the man pushing the shopping cart
# Failed to caption image: ./instance_crops/3045ed93c2534ec2a5cabea89b186bd9/97e6e20dad204fdc9d0da8b9d7ec4e3e.jpg
# Processing 22 images in 7ca5e90766dc4b7bb6a9b3b0d95c99da...
# bad word: image
# invalid caption: the person with blurred image in front of the wall
# Failed to caption image: ./instance_crops/7ca5e90766dc4b7bb6a9b3b0d95c99da/8cacf4350c8e411dbeb0817216a3e58e.jpg
# Processing 3 images in 7365754410624f2f85087003f4ed41ad...
# Processing 6 images in 2bbff07f5b4248eab483ddcf91cfa848...
# Processing 44 images in 4c5c675340d14cd88a65b5e22eb9c9c1...
# Processing 2 images in 2538a745a83f430eb590d48b4743e179...
# Processing 9 images in 599c50b42e294116bd702c9e5cc830a3...
# Processing 15 images in e8bda599a2d44d76a7692caeacb1ba6e...
# Processing 12 images in e233467e827140efa4b42d2b4c435855...
# bad word: photo
# invalid caption: the motion-blurred photograph of the dark blue car with prominent headlights driving through an urban street at night
# Failed to caption image: ./instance_crops/e233467e827140efa4b42d2b4c435855/e3c44d83d35543d1b638c93943d3a180.jpg
# Processing 1 images in 32185f91e68f4069ab3cdd2f4f1a4ff1...
# Processing 5 images in 88084e0150d64dd1949a9cf1493e5188...
# Processing 5 images in d9161e521b1644cea4cb9e3f21ef9f79...
# Processing 3 images in 373bf99c103d4464a7b963a83523fbcb...
# Processing 3 images in c468cdcc838143d480b5b9c835c8380c...
# Processing 16 images in 3ace9decdd1f4ea0915b9862c95ca128...
# Processing 3 images in b3318661150b4d6080886dc702989910...
# Processing 9 images in 73030fb67d3c46cfb5e590168088ae39...
# Processing 11 images in 54cdaaae372d421fa4734d66f51a8c48...
# Processing 4 images in 69a38ccf0894467fbae658d28d4fd10a...
# Processing 24 images in fb73d1a6c16147ee9416faf6b310fadb...
# Processing 9 images in 23e33c8bba1f411ba5871dc074f8dbf8...
# Processing 9 images in 034dee1695304630b0692da8c1f153fc...
# Processing 1 images in 6e81ee0f64274490a403bbd6482c2bf9...
# Processing 8 images in 07aed9dae37340a997535ad99138e243...
# Processing 66 images in 938479858b4849dd8ceddc11c154082b...
# bad word: photo
# invalid caption: the blurry photograph of the street with cars and buildings in the background
# Failed to caption image: ./instance_crops/938479858b4849dd8ceddc11c154082b/30c6aa7fb51f4a45ba9adebf9ea7eaad.jpg
# bad word: photo
# invalid caption: the blurred photograph of the street scene featuring the partially obscured bus on the right, the building with the red awning in the center, and the distant building on the left
# Failed to caption image: ./instance_crops/938479858b4849dd8ceddc11c154082b/77325ff54f2e4368bb5ac5b5f4088b06.jpg
# Processing 25 images in c59fe8015e3743329ec907bc29c93124...
# bad word: image
# invalid caption: the image caption could be: "the gray suv parked at the gas station
# Failed to caption image: ./instance_crops/c59fe8015e3743329ec907bc29c93124/c699890386504d719685c01e45ee19d0.jpg
# bad word: image
# invalid caption: the blurred image of the person walking
# Failed to caption image: ./instance_crops/c59fe8015e3743329ec907bc29c93124/f65b40e8412b455390400faff605f026.jpg
# No images found in the directory: ./instance_crops/fcb40dc8514444c49b1fdc06f80a123b
# Processing 4 images in 3e1f0257a4b8457486651de2d16b61ab...
# Processing 16 images in 1d25e9071ea94891b5eb7554e77a11bb...
# Processing 7 images in bc8f2774ff4946d3965a807a6aa1b64f...
# Processing 5 images in 813213458a214a39a1d1fc77fa52fa34...
# Processing 43 images in 7deb4760e2244f32b57f9d631b535b66...
# Processing 4 images in 19284973bd0342998c37848e931a90d0...
# Processing 2 images in 1c89941a6935484182ca19eddcd3bc77...
# Processing 13 images in 214008f81b8b4b509c730f0c13e9491f...
# Processing 16 images in 3dd2be428534403ba150a0b60abc6a0a...
# Processing 26 images in 0ac05652a4c44374998be876ba5cd6fd...
# Processing 10 images in 567fcd99d0dc4fa088f52b047f4ebdcf...
# bad word: photo
# invalid caption: the blurry photograph of streetlights
# Failed to caption image: ./instance_crops/567fcd99d0dc4fa088f52b047f4ebdcf/70c25833706941e49095f4f34fee1105.jpg
# Processing 21 images in 82024d9f5f7f46dba436cd93c27173c7...
# bad word: image
# invalid caption: the white sedan parked on the right side of the image
# Failed to caption image: ./instance_crops/82024d9f5f7f46dba436cd93c27173c7/a06f2c239c2645cea00d901430a21fc4.jpg
# Processing 20 images in 210add02013a4dfa84b7c5e23058781f...
# Processing 7 images in 7599adab7f3944dc8ac1c88b4f3bb082...
# Processing 8 images in 52fa2df7fde34bd58ee30cff02b73f51...
# Processing 11 images in d3d94f2ce3dc4db4b3ba6f4aa81c3987...
# Processing 25 images in 70368a18644046f898ab836fc8a3c03f...
# Processing 12 images in befb96098dc14988ac468a6bd3cbd4a0...
# Processing 8 images in 2eb0dd074d8e4a328fd2283184c4412e...
# Processing 13 images in 105c227c304b4cb18e98a5be6b2d8302...
# Processing 15 images in 0b8948ee96ac46faad405bf1ffc70bb1...
# Processing 7 images in 2c1f2e5096434cd78919b2ae442d4ba4...
# Processing 10 images in 197a7e4d3de84e57af17b3d65fcb3893...
# Processing 38 images in 390f81ac97474695a727d688240e6fba...
# bad word: photo
# invalid caption: the image is the close-up, low-light photograph of the person's face, showing only the top half, with the focus on the eyes and nose
# Failed to caption image: ./instance_crops/390f81ac97474695a727d688240e6fba/8ece841f44044b5bb8128483d7c7085e.jpg
# Processing 2 images in 25f40f7316954a3e978e24d691e1a117...
# Processing 9 images in bf753f22bc524274bc359467e0be149c...
# Processing 5 images in 7463b2d752f0464f803b07a945ee7c5a...
# Processing 10 images in 69295e26c8d146de94ea5307d8d74819...
# Processing 15 images in 30ae9c1092f6404a9e6aa0589e809780...
# Processing 26 images in f0f7132494bc4045a21868aca13b56f9...
# bad word: photo
# invalid caption: the person with the camerthe taking the photograph
# Failed to caption image: ./instance_crops/f0f7132494bc4045a21868aca13b56f9/87de84387a04479b867a4ab06cbbc531.jpg
# bad word: photo
# invalid caption: the blurred photograph of the busy street
# Failed to caption image: ./instance_crops/f0f7132494bc4045a21868aca13b56f9/011c630ac5304d23b44c23657337d667.jpg
# Processing 37 images in 5d709891c41d423687ae4ea0473cb9c4...
# Processing 15 images in efe3681f556b43e6aa65bf7bfc61a2f8...
# Processing 17 images in e083627747d8499a8c4e94c7abf941e2...
# Processing 46 images in cfeb880362694fa7a428aec2fd139daa...
# bad word: image
# invalid caption: the close-up image of the concrete barrier in an urban setting
# Failed to caption image: ./instance_crops/cfeb880362694fa7a428aec2fd139daa/1d37cb1ffd324b83bf2f747be7e86eb5.jpg
# Processing 23 images in 788c5502523f4d01b3a8de47ec3dadfb...
# Processing 15 images in 7cf32f906f50415786414ce8bbe10e9b...
# Processing 23 images in 64ca274b5f69458bb5d21e0e2e071902...
# Processing 4 images in f24b4682fbb9482aba149534deed1cc9...
# Processing 32 images in ced236f5da704cbcb41249bb6ecc8b68...
# Processing 21 images in 2175d0e84f224ea69907e5c338bde395...
# bad word: image
# invalid caption: the wavy sidewalk in blurry image
# Failed to caption image: ./instance_crops/2175d0e84f224ea69907e5c338bde395/5d30982338144dfcac0a51c7ea48c703.jpg
# bad word: image
# invalid caption: the blurred image of the bus driver
# Failed to caption image: ./instance_crops/2175d0e84f224ea69907e5c338bde395/3b41058f8f624365adffcb35aa4d4bd5.jpg
# Processing 2 images in cb3e964697d448b3bc04a9bc06c9e131...
# Processing 11 images in ab7f4909bc6c4841a12020355a7d505c...
# Processing 9 images in afd73f70ff7d46d6b772d341c08e31a5...
# Processing 18 images in 055a607b74e04001adef097225a8661a...
# Processing 10 images in 692fe09aecae4b1a94f8a3bceedd9b7c...
# bad word: image
# invalid caption: the blurred image of the silver car in motion
# Failed to caption image: ./instance_crops/692fe09aecae4b1a94f8a3bceedd9b7c/9085b862a2ea4016afdae648461f2055.jpg
# Processing 8 images in b0644660d7864451bfc4b3432bb5b47e...
# Processing 19 images in 363bb6c0fdaf465aa54c39f082bb92c6...
# Processing 13 images in 9ac6dff089a84a6d8f066122443a10db...
# Processing 10 images in f13bd38bf9b64d579a63d4e7d750f592...
# bad word: photo
# invalid caption: the man posing for the photograph
# Failed to caption image: ./instance_crops/f13bd38bf9b64d579a63d4e7d750f592/7792866937a94412b6a77ac5c3fdd642.jpg
# Processing 12 images in aacd6706a091407fb1b0e5343d27da7e...
# Processing 26 images in 8fbbe701baf641359129ea166e1674ec...
# Processing 22 images in ed97ee6a3b444ba7800641baab057556...
# Processing 9 images in 0c601ff2bf004fccafec366b08bf29e2...
# Processing 11 images in 78c5f7d7b547483c906d8524a8c3190f...
# Processing 13 images in 88abbe4f3b37466791b2ae58490044d9...
# Processing 9 images in 32bae098e2434a09af1e7983e31fbf5c...
# bad word: photo
# invalid caption: the nighttime photograph capturing the blurry, out-of-focus image of the silver or metallic car parked on the snowy street
# Failed to caption image: ./instance_crops/32bae098e2434a09af1e7983e31fbf5c/ce70d65413be4f90b8a4178e056edf5d.jpg
# Processing 6 images in ee909cb746e44174be804f26bc971efe...
# Processing 7 images in ea0979999bf84ee6a6230b1bde7ec723...
# Processing 5 images in ca6abd081eaf48689f06b5e8fcc9d369...
# Processing 38 images in 70c3b2f2b1f3403083fd44d06cc5abe0...
# ...
# Processing 5 images in 566311b8201e416f9f99463656dcadce...
# Processing 1 images in 9771da5dd7bb4657be34365619e39dab...
# Processing 34 images in 7ef04cdbd04c4b67a22f59502cb8fac6...
# Processing 6 images in ee48ee50025e40b4ae27dbdf84d92825...
# Processing 5 images in e60ef590e3614187b7800db3e5284e1a...
# Processing 31 images in e631037169574c67944176bf079ee75c...
# bad word: photo
# invalid caption: the vintage photograph of the bustling street scene
# Failed to caption image: ./instance_crops/e631037169574c67944176bf079ee75c/479711cf525d4efeaf5dcec62f2c9367.jpg
# Processing 18 images in f634de95cc7043b8b38ceaac67d472cf...
# Processing 23 images in ab8bf18dfce14db4b8213b88f5dc1429...
# Processing 1 images in 85889db3628342a482c5c0255e5347e9...
# Processing 6 images in e6cb595f6df44b3999db28c65f2244ac...
# Processing 9 images in 05d5241d4d5a4c2a9c670dc8c9853c74...
# Processing 9 images in bd210a5bc7004d8c94b68cf6366612a2...
# Processing 18 images in c9d654d4279c4efa9745a25ba6b373ee...
# Processing 16 images in 5557f4edc1464442812293e2ea90a586...
# Processing 34 images in cb0cd06a1dd84271968466d7b65e48f8...
# Processing 4 images in a4bfab3710d4494aa3c9a443c1bf5573...
# Processing 6 images in 080a52cb8f59489b9cddc7b721808088...
# Processing 6 images in 85a9c262809d4ac49d2a9b1f8a1487e8...
# Processing 16 images in 8b43539a55374b6c8ed60c95a42d63a2...
# Processing 25 images in 06c43bc74aff453081ce83eb126a756e...
# Processing 5 images in 9c7062b34e064d6ab42124f3f0be233d...
# Processing 14 images in f444b757d7e2444c889da10f02b73491...
# Processing 3 images in d83994e61a1b431cacf34931801d0c78...
# Processing 15 images in 68fc5e3698a544d1bdf5847b88ad77d4...
# Processing 14 images in d1ece215e0a8442691cb5e380a6fb935...
# Processing 13 images in 53484b9d012842bb98719a9d12b038ca...
# Processing 15 images in 15e1fa06e30e438a98430cc1fd0e8a69...
# Processing 14 images in 555c691be4704ef29559373e031441dd...
# Processing 41 images in 9709626638f5406f9f773348150d02fd...
# Processing 16 images in cffc45a1565446fab5014afb3da169e8...
# Processing 15 images in 4284a8d9b40d42edb9725543db91381e...
# Processing 24 images in 727214583a2a478094d4f093d20c7060...
# bad word: image
# invalid caption: the blurry image of the silver sedan on the city street
# Failed to caption image: ./instance_crops/727214583a2a478094d4f093d20c7060/902428e04e794f0498c57133a5cd0553.jpg
# Processing 18 images in d6e6f5d622474271b695f4c7f07df7bb...
# Processing 5 images in dac50250c406439480be8b44d2c5a634...
# Processing 20 images in 36b7b02f0f034f0595e3437a85554151...
# Processing 7 images in 29dee0b8210b410a9b3421f0cb39019f...
# Processing 28 images in 5fc7c5dfc56b4971b14005bc53f69908...
# image too small: ./instance_crops/5fc7c5dfc56b4971b14005bc53f69908/0f6a5cf8544d40e593aa06cee4b3b991.jpg
# Failed to caption image: ./instance_crops/5fc7c5dfc56b4971b14005bc53f69908/0f6a5cf8544d40e593aa06cee4b3b991.jpg
# Processing 7 images in f4395dd8e4004f12a8dec3079a93d804...
# Processing 15 images in 8d267899e2e843d4905fafd1f12c0a20...
# Processing 38 images in cab845a2e8864482993ac62811f879c1...
# Processing 5 images in 696a45dbd11346b794fdce43fa0a1770...
# Processing 21 images in 8c84164e752a4ab69d039a07c898f7af...
# Processing 25 images in c525507ee2ef4c6d8bb64b0e0cf0dd32...
# Processing 12 images in 295c6c85275e4376bc8446b4a76504cd...
# Processing 25 images in a178a1b5415f45c08d179bd2cacdf284...
# Processing 5 images in 8857cf15fa7049a6b000490835d3b9fc...
# Processing 27 images in 47a73fb6a41a4c4b9fe2897254dd3671...
# Processing 9 images in 2a334f5c4615465f86a250d4758a2d7d...
# bad word: photo
# invalid caption: the dark, blurry photograph, low light conditions,  vehicle with illuminated headlight, road with scattered debris, night, indistinct background, no clear identifiable landmarks
# Failed to caption image: ./instance_crops/2a334f5c4615465f86a250d4758a2d7d/2ede8f32588d4d3080c80e3dba645e85.jpg
# bad word: photo
# invalid caption: the blurry photograph of the nighttime street with the single, prominent streetlamp casting the dim glow, and the car's headlights illuminating the patch of road ahead, with an indistinct, dark background suggesting trees or bushes lining the sides of the road
# Failed to caption image: ./instance_crops/2a334f5c4615465f86a250d4758a2d7d/c85ecc56fc154d4cb8a7d37fbaf02fc2.jpg
# Processing 18 images in f0f120e4d4b0441da90ec53b16ee169d...
# Processing 18 images in ceca737af78440118b7b394a54723454...
# Processing 17 images in 77c9f156f8594ed59dcdacb8b877a7ac...
# Processing 16 images in aa54277d163d419b9f952b014112643e...
# Processing 18 images in b57e1a48e584451f8f966ab083c8d07d...
# bad word: image
# invalid caption: the blurred image of the moving vehicle on the street, captured at night
# Failed to caption image: ./instance_crops/b57e1a48e584451f8f966ab083c8d07d/0754a4bd4775421fb6fdcbeae15457a9.jpg
# Processing 1 images in 50ff554b3ecb4d208849d042b7643715...
# Processing 12 images in 5301151d8b6a42b0b252e95634bd3995...
# Processing 31 images in 1847e3fc11ab466d95f82e6c7031f33d...
# Processing 1 images in 90d616aaefc4429380388205ebb23398...
# Processing 3 images in 1d4db80d13f342aba4881b38099bc4b7...
# Processing 11 images in 34a9823fac0d4b9db30898e00b5f9f9c...
# Processing 9 images in 30e77a3561ce4f1bb4fd90e322ea29d7...
# Processing 1 images in 76b0df6376e246d284c9be42b1fc6be6...
# Processing 91 images in aa45d94630be481787f20121ce89a605...
# bad word: image
# invalid caption: the blurred streetcar image
# Failed to caption image: ./instance_crops/aa45d94630be481787f20121ce89a605/79d2c99aabd24462a3d86171bbfd75d4.jpg
# Processing 7 images in 521f01dfc8c9402e8309e047e2eea112...
# Processing 42 images in fb20ca9935c4439e8125ba830abcf9dc...
# bad word: photo
# invalid caption: the close-up of the person holding the camera, likely photographing the street scene
# Failed to caption image: ./instance_crops/fb20ca9935c4439e8125ba830abcf9dc/e3bd17c57b934cd59c55abd063fceab4.jpg
# Processing 6 images in c74a3a7265ae45f99f65628fbd7cd2a4...
# Processing 1 images in 55b44b64f35c48689cdca8c39b672db4...
# Processing 5 images in fee7ac5f5c1e4943877cd20d6e069427...
# Processing 1 images in 23663ff8f4614b8bb005d67e51a69283...
# Processing 3 images in 85d5e2548a5e454fa65a739ac0ac55c2...
# Processing 2 images in 21a7ba093614493b83838b9656b3558d...
# Processing 23 images in 4772f5283211444eaabd463cd341d360...
# Processing 29 images in dc8302cfccdb4812a0a4a60dde595e18...
# No images found in the directory: ./instance_crops/21464a6831c1443db294d1b56a7a33a5
# Processing 10 images in 9833ac6de5ae418f9e6d0eeb58e72beb...
# Processing 55 images in bcb05cffb5814973a6cff4fbdca2b99b...
# bad word: photo
# invalid caption: the blurred, out of focus photograph of the car
# Failed to caption image: ./instance_crops/bcb05cffb5814973a6cff4fbdca2b99b/f9c39ac1a3554298a18a49fe61c48526.jpg
# image too small: ./instance_crops/bcb05cffb5814973a6cff4fbdca2b99b/32da9c629faf43168fa7469ae9b6e62c.jpg
# Failed to caption image: ./instance_crops/bcb05cffb5814973a6cff4fbdca2b99b/32da9c629faf43168fa7469ae9b6e62c.jpg
# Processing 8 images in 84f4c0747550493f959595dae6785cd3...
# bad word: picture
# invalid caption: the man in blue hoodie taking picture of girl on the street
# Failed to caption image: ./instance_crops/84f4c0747550493f959595dae6785cd3/3cb920a7f21f4353954aeef07c94b3c5.jpg
# Processing 38 images in da783af4b5124333911684dbaf31d969...
# Processing 2 images in 2135a00f664d4a3bbfb938e007befa06...
# Processing 47 images in 2ed0fcbfc214478ca3b3ce013e7723ba...
# Processing 10 images in 865c607c8ef44f13b39744a0de110740...
# bad word: photo
# invalid caption: the blurry photo of the city street at night, featuring the pedestrian crossing with yellow lines and the dark, out-of-focus streetlamp casting the faint glow
# Failed to caption image: ./instance_crops/865c607c8ef44f13b39744a0de110740/40bd3f390ef848c29660a378094294f0.jpg
# Processing 23 images in 69e393da7cb54eb6bea7927a2af0d1ee...
# Processing 15 images in 098c11f50ff2425a9ff994e004de1216...
# Processing 15 images in e54f4a36a8b94aebbe4189186dee8f05...
# Processing 3 images in 3032b651c72e4b5c86d4dea1b4930689...
# Processing 27 images in d95a36c034344ae2ac11daf2ba1b2c60...
# Processing 7 images in 2987b4494fcc4639bdd6d714a94b2c72...
# Processing 15 images in 380ff00ec86447e3b986edc8e82ffba7...
# bad word: image
# invalid caption: the blurred image of the gray sedan parked at the curb next to the sidewalk
# Failed to caption image: ./instance_crops/380ff00ec86447e3b986edc8e82ffba7/462a8cd182644ebaa53e7d2794330e7f.jpg
# Processing 2 images in 83773bcf46ac486383529098de0542dd...
# Processing 14 images in a2b005c4dd654af48194ada18662c8ca...
# Processing 21 images in f57957ebc5654b649a0786d993b64be4...
# Processing 9 images in b94fbf78579f4ff5ab5dbd897d5e3199...
# Processing 9 images in 5560a973257e407b8d5bf9fb92b1e0f3...
# Processing 13 images in e036014a715945aa965f4ec24e8639c9...
# Processing 7 images in efa5c96f05594f41a2498eb9f2e7ad99...
# Processing 36 images in 3dd9ad3f963e4f588d75c112cbf07f56...
# Processing 8 images in 66be189398d74681a8b8db4b7dd52259...
# Processing 29 images in c65c4acf86954f8cbd53a3541a3bfa3a...
# bad word: image
# invalid caption: the blurry image of the green car parked on the street at night
# Failed to caption image: ./instance_crops/c65c4acf86954f8cbd53a3541a3bfa3a/cb554c3325d74f6b984ac12199c285cf.jpg
# Processing 15 images in 66461d94f2e44d39a90843ff2dce11e8...
# Processing 21 images in 60111bb5388f4195b98555d4d4b89618...
# Processing 25 images in 980ddcb62e294608bd4235b0dfd517f4...
# bad word: image
# invalid caption: the image depicts the dark, abstract scene, primarily in black and deep blues, with hints of lighter shades suggesting the textured or patterned surface
# Failed to caption image: ./instance_crops/980ddcb62e294608bd4235b0dfd517f4/1049b67327934b34ac4b3abf84189a62.jpg
# Processing 22 images in 643ee37539844cb2b0453fd031a3afdd...
# bad word: image
# invalid caption: the gray sedan on the right side of the image, in the street scene
# Failed to caption image: ./instance_crops/643ee37539844cb2b0453fd031a3afdd/333274a4b31f4b798e58c47342af725c.jpg
# Processing 17 images in 1c76efe7d0b048bc815c0445eeaa76ab...
# Processing 8 images in 1f23540a109243438a5e3bd47e70105d...
# Processing 23 images in e3d714da71d2477695a055716ede7130...
# bad word: image
# invalid caption: the image shows the small, brown dog walking on the sidewalk next to the parked silver car
# Failed to caption image: ./instance_crops/e3d714da71d2477695a055716ede7130/d747997810dc490dad94c23c18e3cdec.jpg
# Processing 19 images in 2376fcdd28a44b83962289664cee55b7...
# bad word: image
# invalid caption: the street light, blurred image
# Failed to caption image: ./instance_crops/2376fcdd28a44b83962289664cee55b7/fb03feb9d8f34fc583caef2cf0d116b4.jpg
# Processing 44 images in 312102fd97de4bd4859374946e24ccdc...
# Processing 9 images in 43d5f10c855048b9963c9eb288a8a001...
# Processing 8 images in 2ca15f59d656489a8b1a0be4d9bead4e...
# Processing 25 images in 6746ba640c0e45c7961efbe6af51757e...
# Processing 10 images in 9f3c8453d03d4df5946444757376b826...
# Processing 7 images in 0cc28fe2c1064fb9a51f1647c28ca564...
# Processing 21 images in 5890face846e47a899246159b7c30bd7...
# No images found in the directory: ./instance_crops/f8ef029224b84d14843db98a76a7f4a1
# Processing 8 images in 1fbcc26ebf6948bb964d3ae74939e8ea...
# Processing 13 images in 406a61a4d394432e95a7e8426a97551f...
# Processing 1 images in 796e7ae080984a0ab2b96ce80f18ca3b...
# Processing 10 images in d8a5dd6087de4e808c61c27f91e8216e...
# Processing 13 images in c7b8d96173bf41dc8df8c0d16adfc71e...
# Processing 20 images in 08110c8640454affb5167801442a85fd...
# Processing 9 images in 66134aebdaca4aca82aec91ec8c6245e...
# Processing 35 images in 85651af9c04945c3a394cf845cb480a6...
# Processing 11 images in 9088db17416043e5880a53178bfa461c...
# Processing 7 images in 6d872d1448814fd189e631b1187c3771...
# Processing 10 images in 13be0238abba499e95ba4e6404b22223...
# Processing 13 images in 96a410b8fe5e4b57bf69b844bfd4d28c...
# Processing 5 images in f98a50e675b14266a6c53cb25a0351fa...
# bad word: photo
# invalid caption: the nighttime car photograph showing the black sedan with bright headlights and license plate visible from the back
# Failed to caption image: ./instance_crops/f98a50e675b14266a6c53cb25a0351fa/c8baf959030243089dddc685ebfdd3a4.jpg
# bad word: photo
# invalid caption: the blurry photograph of the parked car
# Failed to caption image: ./instance_crops/f98a50e675b14266a6c53cb25a0351fa/2f4a11978055404cb430222d5a40f772.jpg
# Processing 14 images in 81227a12571240e0b9d537165f57e177...
# Processing 22 images in 4ed628299b1e45a3a73704e8cf8287a9...
# Processing 7 images in fb3aaad97849430cbc32891319c9be10...
# Processing 11 images in 433a14f8dcf5457fb2c4def5c749122a...
# bad word: photo
# invalid caption: the pink backpack and jeans in blurry city street photo
# Failed to caption image: ./instance_crops/433a14f8dcf5457fb2c4def5c749122a/405659ddfd274e109827803de2b616d5.jpg
# Processing 18 images in c34206e65a1442828b950b0ca52098b7...
# Processing 29 images in 9f5f2211d6f943a89dd87bbe9703539d...
# Processing 42 images in 3014465d5958427aac89c4f15b6050dd...
# Processing 12 images in 400b708de5d7434d8964da4a0246d164...
# Processing 14 images in 35c3bc100e4b4e5089820986d3f50fa3...
# Processing 11 images in bd916d78cb3149999182fb3ce4eb8a8d...
# Processing 2 images in bb028034cb474e3da8953f83752a70a9...
# Processing 21 images in c7604a179ea94e45857ec2c16416e5ad...
# Processing 13 images in 49eb09ab4c4142268131125d6e619a0c...
# Processing 10 images in 31cb85777b814e0ab6ae6d146964b6ae...
# Processing 9 images in 36e3167610cc48eabcaad06a72479ac7...
# Processing 34 images in 9544516643a14926bf750fc71c1b307d...
# bad word: image
# invalid caption: the blurry image of the city street
# Failed to caption image: ./instance_crops/9544516643a14926bf750fc71c1b307d/ccf23451c0824c67beb3bc489ea2a8c1.jpg
# Processing 6 images in 96e5f1f0944946f391b4ef33ad623008...
# Processing 3 images in 265f002f02d447ad9074813292eef75e...
# Processing 6 images in 857922568e4e4fb89c3ee3010eb93c7c...
# Processing 23 images in 55638ae3a8b34572aef756ee7fbce0df...
# Processing 9 images in 09f67057dd8346388b28f79d9bb1cf04...
# Processing 14 images in d825d5544592463e8c138473502dfeea...
# bad word: photo
# invalid caption: the red-shirted pedestrian taking photo
# Failed to caption image: ./instance_crops/d825d5544592463e8c138473502dfeea/7945bc9af5f74ee09927e35988071d0f.jpg
# Processing 21 images in fe3aa64e4339456186c38c6308f5fb1a...
# Processing 25 images in 2ffd7e2a1daf4b928464ddb2ed3dca59...
# image too small: ./instance_crops/2ffd7e2a1daf4b928464ddb2ed3dca59/031c2f40848346919874482cb0778f7d.jpg
# Failed to caption image: ./instance_crops/2ffd7e2a1daf4b928464ddb2ed3dca59/031c2f40848346919874482cb0778f7d.jpg
# bad word: photo
# invalid caption: the image is the blurry, low-resolution photograph capturing the portion of the street scene
# Failed to caption image: ./instance_crops/2ffd7e2a1daf4b928464ddb2ed3dca59/b8002581097f40cfadc73244aaf863f1.jpg
# Processing 24 images in 24d0c3ea8a2049468201c055667d6bc3...
# Processing 5 images in e005041f659c47e194cd5b18ea6fc346...
# Processing 29 images in 1e3f0bd8063a4084b7104345b20bfb80...
# Processing 6 images in 748894952b00431186308b387c2f424c...
# Processing 8 images in e209e66ff7834490b212c16cb12a1ce9...
# Processing 12 images in 01c3f5e39956402da3e37845632fadca...
# Processing 4 images in 04219bfdc9004ba2af16d3079ecc4353...
# Processing 8 images in c0cb50847c3949a0b4baf2e200ac897c...
# Processing 11 images in 848ac962547c4508b8f3b0fcc8d53270...
# Processing 10 images in afbc2583cc324938b2e8931d42c83e6b...
# Processing 34 images in f92422ed4b4e427194a4958ccf15709a...
# Processing 21 images in 52678e6091214431bf9f3b41e5eeaa24...
# Processing 6 images in 57f5503bf63144b8bf450315e860f58e...
# Processing 11 images in e6f1a7e6218a4737bfedc6af90926b3e...
# Processing 10 images in 8383c0b1422b46ad90e2a64ff3e91fcf...
# Processing 41 images in cc8c0bf57f984915a77078b10eb33198...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
